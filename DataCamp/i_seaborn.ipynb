# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
num = {
    'height_cm': [22,59,78,43,32,55,34,54,65,23,14,53],
    'weight_kg': [40,78,84,67,78,98,45,64,83,45,48,99]
}
num = pd.DataFrame(num)

# %%
num['height_cm'].corr(num['weight_kg'])
# Out:
# 0.7552912816753897

# %%
sns.scatterplot(data = num, x =  'height_cm', y ='weight_kg' )
# Out:
# <Axes: xlabel='height_cm', ylabel='weight_kg'>

# %%
sns.lmplot(data = num, x =  'height_cm', y ='weight_kg' ,ci = 40)
