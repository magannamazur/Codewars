# %%
import cv2
# from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

# %%
def cv2_imshow(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()

# %%
cv2.__version__
# Out:
# '4.7.0'

# %%
# !git clone https://github.com/matzim95/ML-datasets

# %%
img = cv2.imread('ML-datasets/images/lena.png')
cv2_imshow(img)

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt

def show_histogram(image):
  ax1 = plt.subplot(331)
  plt.xlim([0,256])
  plt.ylim([0,5000])
  for i, col in enumerate(['b', 'g', 'r']):

    hist = cv2.calcHist([image], [i], None, [256], [0,255])
    ax1 = plt.subplot(3,1,i+1, sharey=ax1)
    plt.plot(hist, color=col)

    if i<2:
      plt.setp(ax1.get_xticklabels(), visible=False)

  plt.show()

show_histogram(img)
# Out:
# /tmp/ipykernel_22019/3661975825.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot(3,1,i+1, sharey=ax1)

# %%
def show_hsv_equalized(image):
  new_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
  H, S, V = cv2.split(new_image)
  eq_S = cv2.equalizeHist(S)
  eq_V = cv2.equalizeHist(V)
  eq_image = cv2.cvtColor(cv2.merge([H, eq_S, eq_V]), cv2.COLOR_HSV2BGR)
  cv2_imshow(eq_image)
  show_histogram(eq_image)

show_hsv_equalized(img)
# Out:
# /tmp/ipykernel_22019/3661975825.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot(3,1,i+1, sharey=ax1)

# %%
img2 = cv2.imread('ML-datasets/images/gory_lc.png')
cv2_imshow(img2)
show_histogram(img2)
# Out:
# /tmp/ipykernel_22019/3661975825.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot(3,1,i+1, sharey=ax1)

# %%
show_hsv_equalized(img2)
# Out:
# /tmp/ipykernel_22019/3661975825.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot(3,1,i+1, sharey=ax1)
