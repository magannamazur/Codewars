# %%
import cv2
# from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

# %%
# wczytanie obrazu
img = cv2.imread('ML-datasets/images/gory_lc.png')
# od razu - zamiana na RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img = img / 255

# %%
# szum gaussowski - średnia 0, std 1/10
random_noise = np.random.randn(*img.shape) / 10

# %%
np.mean(random_noise), np.std(random_noise)
# Out:
# (6.103760553094844e-05, 0.04997904792843836)

# %%
# dodanie szumu do obrazu
noisy_img = np.add(img, random_noise)

# %%
# obraz z szumem
plt.imshow(noisy_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# oryginalny obraz
plt.imshow(img)

# %% [markdown]
# # Wczytanie jednego obrazu z danych CIFAR

# %%
import keras
from tensorflow.keras.utils import to_categorical
# Out:
# 2023-06-17 12:00:52.643524: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-17 12:00:52.698832: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-17 12:00:52.699797: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-17 12:00:54.203112: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# wczytanie danych
(train_x, train_y), (test_x, test_y) = keras.datasets.cifar10.load_data()

# 0-255 to 0-1
train_x = train_x/255 
test_x = test_x/255

# Change the labels from integer to categorical data
train_y_one_hot = to_categorical(train_y) 
test_y_one_hot = to_categorical(test_y)

# %%
# bierzemy jeden obrazek - o indeksie 1000
img = test_x[1000]

# %%
plt.imshow(img)
