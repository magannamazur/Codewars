# %%
## Wczytaj biblioteki

# %%
import warnings # Supress warnings 
warnings.filterwarnings('ignore')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns # Visualization
import matplotlib.pyplot as plt # Visualization

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
may_flights = flights.query("month == 'May'")
may_flights
# Out:
#      year month  passengers
# 4    1949   May         121
# 16   1950   May         125
# 28   1951   May         172
# 40   1952   May         183
# 52   1953   May         229
# 64   1954   May         234
# 76   1955   May         270
# 88   1956   May         318
# 100  1957   May         355
# 112  1958   May         363
# 124  1959   May         420
# 136  1960   May         472

# %%
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
## wczytraj csv Aquifer_Petrignano.csv

# %%
df = pd.read_csv("Aquifer_Petrignano.csv")
df
# Out:
#             Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0     14/03/2006                    NaN                    -22.48
# 1     15/03/2006                    NaN                    -22.38
# 2     16/03/2006                    NaN                    -22.25
# 3     17/03/2006                    NaN                    -22.38
# 4     18/03/2006                    NaN                    -22.60
# ...          ...                    ...                       ...
# 5218  26/06/2020                    0.0                    -25.68
# 5219  27/06/2020                    0.0                    -25.80
# 5220  28/06/2020                    0.0                    -25.80
# 5221  29/06/2020                    0.0                    -25.78
# 5222  30/06/2020                    0.0                    -25.91
#
#       Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# 0                       -22.18                       NaN
# ...

# %%
## usun wiersze które sa sa nullowe w Rainfall_Bastia_Umbra

# %%
df = df[df.Rainfall_Bastia_Umbra.notna()].reset_index(drop=True)
df
# Out:
#             Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0     01/01/2009                    0.0                    -31.96
# 1     02/01/2009                    0.0                    -32.03
# 2     03/01/2009                    0.0                    -31.97
# 3     04/01/2009                    0.0                    -31.91
# 4     05/01/2009                    0.0                    -31.94
# ...          ...                    ...                       ...
# 4194  26/06/2020                    0.0                    -25.68
# 4195  27/06/2020                    0.0                    -25.80
# 4196  28/06/2020                    0.0                    -25.80
# 4197  29/06/2020                    0.0                    -25.78
# 4198  30/06/2020                    0.0                    -25.91
#
#       Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# 0                       -31.14                       5.2
# ...

# %%
## sprawdź ilośc nulli przez df info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5223 entries, 0 to 5222
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  5223 non-null   object
#  1   Rainfall_Bastia_Umbra                 4199 non-null   float64
#  2   Depth_to_Groundwater_P24              5168 non-null   float64
#  3   Depth_to_Groundwater_P25              5184 non-null   float64
#  4   Temperature_Bastia_Umbra              4199 non-null   float64
#  5   Temperature_Petrignano                4199 non-null   float64
#  6   Volume_C10_Petrignano                 5025 non-null   float64
#  7   Hydrometry_Fiume_Chiascio_Petrignano  4199 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 326.6+ KB

# %%
## usun kolumny 'Depth_to_Groundwater_P24', 'Temperature_Petrignano'

# %%
df = df.drop(['Depth_to_Groundwater_P24', 'Temperature_Petrignano'], axis=1)
df
# Out:
#             Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P25  \
# 0     14/03/2006                    NaN                    -22.18
# 1     15/03/2006                    NaN                    -22.14
# 2     16/03/2006                    NaN                    -22.04
# 3     17/03/2006                    NaN                    -22.04
# 4     18/03/2006                    NaN                    -22.04
# ...          ...                    ...                       ...
# 5218  26/06/2020                    0.0                    -25.07
# 5219  27/06/2020                    0.0                    -25.11
# 5220  28/06/2020                    0.0                    -25.19
# 5221  29/06/2020                    0.0                    -25.18
# 5222  30/06/2020                    0.0                    -25.25
#
#       Temperature_Bastia_Umbra  Volume_C10_Petrignano  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# ...

# %%
## zmien nazwy kolumn ['Date', 'Rainfall', 'Depth_to_Groundwater', 'Temperature', 'Drainage_Volume', 'River_Hydrometry']

# %%
df.columns = ['Date', 'Rainfall', 'Depth_to_Groundwater', 'Temperature', 'Drainage_Volume', 'River_Hydrometry']
df
# Out:
#             Date  Rainfall  Depth_to_Groundwater  Temperature  \
# 0     14/03/2006       NaN                -22.18          NaN
# 1     15/03/2006       NaN                -22.14          NaN
# 2     16/03/2006       NaN                -22.04          NaN
# 3     17/03/2006       NaN                -22.04          NaN
# 4     18/03/2006       NaN                -22.04          NaN
# ...          ...       ...                   ...          ...
# 5218  26/06/2020       0.0                -25.07         25.7
# 5219  27/06/2020       0.0                -25.11         26.2
# 5220  28/06/2020       0.0                -25.19         26.9
# 5221  29/06/2020       0.0                -25.18         26.9
# 5222  30/06/2020       0.0                -25.25         27.3
#
#       Drainage_Volume  River_Hydrometry
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# ...

# %%
## wyznacz w nasza kolumne churnowa Depth_to_Groundwater i daj ja w liście (przypisz do zmiennej)

# %%
targets = ['Depth_to_Groundwater']

# %%
## z pozostalych kolumn wyznacz liste kolumn do treningu

# %%
features = [feature for feature in df.columns if feature not in targets]
features
# Out:
# ['Date', 'Rainfall', 'Temperature', 'Drainage_Volume', 'River_Hydrometry']

# %%
## pokaz 5 górnych wierszy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5223 entries, 0 to 5222
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  5223 non-null   object
#  1   Rainfall              4199 non-null   float64
#  2   Depth_to_Groundwater  5184 non-null   float64
#  3   Temperature           4199 non-null   float64
#  4   Drainage_Volume       5025 non-null   float64
#  5   River_Hydrometry      4199 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 245.0+ KB

# %%
## przekonweruj date na zmienna date

# %%
from datetime import datetime, date 
df['Date'] = pd.to_datetime(df.Date, format = '%d/%m/%Y')

# %%
df
# Out:
#            Date  Rainfall  Depth_to_Groundwater  Temperature  Drainage_Volume  \
# 0    2006-03-14       NaN                -22.18          NaN              NaN
# 1    2006-03-15       NaN                -22.14          NaN              NaN
# 2    2006-03-16       NaN                -22.04          NaN              NaN
# 3    2006-03-17       NaN                -22.04          NaN              NaN
# 4    2006-03-18       NaN                -22.04          NaN              NaN
# ...         ...       ...                   ...          ...              ...
# 5218 2020-06-26       0.0                -25.07         25.7       -29930.688
# 5219 2020-06-27       0.0                -25.11         26.2       -31332.960
# 5220 2020-06-28       0.0                -25.19         26.9       -32120.928
# 5221 2020-06-29       0.0                -25.18         26.9       -30602.880
# 5222 2020-06-30       0.0                -25.25         27.3       -31878.144
#
#       River_Hydrometry
# ...

# %%
## zrób 5 wykresy liniowe dla Rainfall, Temperature, Drainage_Volume, River_Hydrometry, Depth_to_Groundwater

# %%
df.Date
# Out:
# 0      2006-03-14
# 1      2006-03-15
# 2      2006-03-16
# 3      2006-03-17
# 4      2006-03-18
#           ...
# 5218   2020-06-26
# 5219   2020-06-27
# 5220   2020-06-28
# 5221   2020-06-29
# 5222   2020-06-30
# Name: Date, Length: 5223, dtype: datetime64[ns]

# %%
f, ax = plt.subplots(nrows=5, ncols=1, figsize=(15, 25))

sns.lineplot(x=df.Date, y=df.Rainfall.fillna(np.inf), ax=ax[0], color='dodgerblue')
ax[0].set_title('Feature: Rainfall', fontsize=14)
ax[0].set_ylabel(ylabel='Rainfall', fontsize=14)


sns.lineplot(x=df.Date, y=df.Temperature.fillna(np.inf), ax=ax[1], color='dodgerblue',label='Bastia Umbra')
ax[1].set_title('Feature: Temperature', fontsize=14)
ax[1].set_ylabel(ylabel='Temperature', fontsize=14)


sns.lineplot(x=df.Date, y=df.Drainage_Volume.fillna(np.inf), ax=ax[2], color='dodgerblue')
ax[2].set_title('Feature: Volume', fontsize=14)
ax[2].set_ylabel(ylabel='Volume', fontsize=14)


sns.lineplot(x=df.Date, y=df.River_Hydrometry.fillna(np.inf), ax=ax[3], color='dodgerblue')
ax[3].set_title('Feature: Hydrometry', fontsize=14)
ax[3].set_ylabel(ylabel='Hydrometry', fontsize=14)


sns.lineplot(x=df.Date, y=df.Depth_to_Groundwater.fillna(np.inf), ax=ax[4], color='dodgerblue')
ax[4].set_title('Target: Depth to Groundwater', fontsize=14)
ax[4].set_ylabel(ylabel='Depth to Groundwater', fontsize=14)


for i in range(5):
    ax[i].set_xlim([date(2009, 1, 1), date(2020, 6, 30)])

plt.show()

# %%
## użyj subplots 5 na 1 z figsizem 15 na 25
## przypisz to do figure i ax
## użyj lineplota
## y daj jako df.Rainfall.fillna(np.inf)
## wstaw set_title i set_ylabel
## wstaw za pomoca set_xlim dla każdego axa po pętli daty 2009,1,1 do 2020,6,30

# %%
## zrób dwa wykresy liniowe River_Hydrometry i dla Drainage_Volume 
## gdzie na niebiesko będa wartości która sa a na zółto których nie ma

# %%
## wypełnij dane i wyświetl zółta linia - dodatkowe
