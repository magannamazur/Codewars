# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data=df, x='day', order=df['day'].unique())
plt.show()

# %%
sns.countplot(data=df, x='day', order=df['day'].value_counts(ascending=True).index)
plt.show()

# %%
sns.countplot(data=df, x='day', order=df['day'].value_counts(ascending=False).index)
plt.show()

# %%
sns.countplot(data=df, x='day', hue='sex')
plt.show()

# %%
ax = sns.countplot(data=df, x='day', hue='sex', color='aquamarine')
for label in ax.containers:
    ax.bar_label(label)
    
plt.show()

# %%
pip install palmerpenguins
# Out:
# Collecting palmerpenguins
#   Downloading palmerpenguins-0.1.4-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from palmerpenguins) (1.23.5)
# Requirement already satisfied: pandas in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from palmerpenguins) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from pandas->palmerpenguins) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from pandas->palmerpenguins) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from pandas->palmerpenguins) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->palmerpenguins) (1.16.0)
# Installing collected packages: palmerpenguins
# Successfully installed palmerpenguins-0.1.4
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from palmerpenguins import load_penguins

# %%
penguins = load_penguins()

sns.displot(penguins, x="flipper_length_mm")

# %%
penguins = load_penguins()

sns.displot(penguins, x="flipper_length_mm", binwidth=3)

# %%
penguins = load_penguins()

sns.displot(penguins, x="flipper_length_mm", hue='species', element='step')

# %%
sns.displot(penguins, x='flipper_length_mm', kind='kde')

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0       Adelie  Torgersen            39.1           18.7              181.0  \
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %%
penguins = penguins.drop(columns='year')

# %%
sns.pairplot(penguins, hue='species')
